# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

curr_wor_dir = os.getcwd()
data = '/data_ipynb/Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month-2.csv'
final_data_dir = curr_wor_dir + data

# Read the CSV file
df = pd.read_csv(final_data_dir)
df
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State         City  \
# 0         91982         1       77494        zip        TX    TX         Katy
# 1         61148         2        8701        zip        NJ    NJ     Lakewood
# 2         91940         3       77449        zip        TX    TX         Katy
# 3         62080         4       11368        zip        NY    NY     New York
# 4         91733         5       77084        zip        TX    TX      Houston
# ...         ...       ...         ...        ...       ...   ...          ...
# 26328    100030     39992       98934        zip        WA    WA     Kittitas
# 26329     92085     39992       77661        zip        TX    TX          NaN
# 26330     64277     39992       15731        zip        PA    PA        Coral
# 26331     98183     39992       95419        zip        CA    CA  Camp Meeker
# 26332     67368     39992       22722        zip        VA    VA      Haywood
#
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 0         91982         1       77494        zip        TX    TX
# 1         61148         2        8701        zip        NJ    NJ
# 2         91940         3       77449        zip        TX    TX
# 3         62080         4       11368        zip        NY    NY
# 4         91733         5       77084        zip        TX    TX
# ...         ...       ...         ...        ...       ...   ...
# 26311     97161     39992       93222        zip        CA    CA
# 26316     76723     39992       43525        zip        OH    OH
# 26317     63002     39992       13162        zip        NY    NY
# 26320     93402     39992       80453        zip        CO    CO
# 26331     98183     39992       95419        zip        CA    CA
#
#                      City                                  Metro  \
# 0                    Katy   Houston-The Woodlands-Sugar Land, TX
# ...

# %%
df_top_20=df.head(20)

subsets={}
for index, row in df_top_20.iterrows():
    subset_id=row["RegionID"]
    subset=pd.DataFrame({
    "date":df.columns[9:],
    "cost":row[9:].values,
    })
    subsets[subset_id] = subset
    globals()[f"df_{subset_id}"]=subset
for subset_id, subset_df in subsets.items():
    print(f"Dataset{subset_id}:")
    print(subset_df)
    print()
# Out:
# Dataset91982:
#            date           cost
# 0    2000-01-31  209044.032747
# 1    2000-02-29  209225.464086
# 2    2000-03-31   209710.27032
# 3    2000-04-30  210689.474219
# 4    2000-05-31  210724.500177
# ..          ...            ...
# 293  2024-06-30  495365.132391
# 294  2024-07-31  494987.724791
# 295  2024-08-31  495393.290898
# 296  2024-09-30  496081.013222
# 297  2024-10-31  497199.835159
#
# [298 rows x 2 columns]
#
# Dataset61148:
#            date           cost
# 0    2000-01-31  138154.018163
# 1    2000-02-29  138724.218828
# 2    2000-03-31   139109.61338
# 3    2000-04-30  140085.976636
# 4    2000-05-31  141101.750123
# ..          ...            ...
# 293  2024-06-30  617370.077059
# 294  2024-07-31  622270.010994
# 295  2024-08-31  627535.387875
# 296  2024-09-30  633736.078245
# 297  2024-10-31  639283.596573
#
# [298 rows x 2 columns]
#
# Dataset91940:
#            date           cost
# 0    2000-01-31  102286.114622
# 1    2000-02-29   102300.24837
# ...

# %%
df_62080.to_csv("df_62080.csv", index=False)

# %%
df_91733
# Out:
#            date           cost
# 0    2000-01-31  101363.959236
# 1    2000-02-29  101321.448221
# 2    2000-03-31  101141.451806
# 3    2000-04-30  101059.217991
# 4    2000-05-31  101034.755772
# ..          ...            ...
# 293  2024-06-30   272450.11478
# 294  2024-07-31  272160.688023
# 295  2024-08-31  271890.755361
# 296  2024-09-30  271640.385722
# 297  2024-10-31   271138.57461
#
# [298 rows x 2 columns]
